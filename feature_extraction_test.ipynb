# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

from audio_feature_extraction import AudioFeatureExtractor

import warnings
warnings.filterwarnings('ignore')

# %%
afe = AudioFeatureExtractor()

# %%
x2 = afe.get_audio('raw_data/XC100213.mp3')

# %%
x = afe.get_audio('raw_data/XC103096.mp3')
len(x)
# Out:
# 1775669

# %%
test_df2 = pd.DataFrame(afe.extract_chroma_stft(x))

# %%
len(x2)
# Out:
# 141664

# %%
test_df = pd.DataFrame(afe.extract_chroma_stft(x2))

# %%
np.mean(test_df, axis=1)
# Out:
# 0     0.686565
# 1     0.748007
# 2     0.802768
# 3     0.824809
# 4     0.797385
# 5     0.763542
# 6     0.706435
# 7     0.661290
# 8     0.629208
# 9     0.624689
# 10    0.605377
# 11    0.586770
# dtype: float32

# %%
np.mean(test_df2, axis=1)
# Out:
# 0     0.664664
# 1     0.635491
# 2     0.649223
# 3     0.660020
# 4     0.678131
# 5     0.672713
# 6     0.658155
# 7     0.639778
# 8     0.621895
# 9     0.609615
# 10    0.628145
# 11    0.662255
# dtype: float32

# %%
pd.DataFrame(afe.extract_mfcc(x))
# Out:
#          0           1           2           3           4           5      \
# 0  -636.656494 -620.934937 -622.916077 -628.396606 -628.033813 -634.898132
# 1    53.794327   65.366516   66.904587   55.081215   55.370346   55.056786
# 2     8.418866   14.101810   23.963083   28.534458   23.965734   20.958710
# 3    15.326878   23.720459   31.160717   39.747478   32.451572   30.470856
# 4     0.924831    3.861347    8.972609   13.829273   16.895962   12.317184
# 5    13.143365    8.636906   11.284533   18.218132   30.724672   23.673332
# 6    11.668930   15.000103   13.234360   11.729802   20.837599    5.654499
# 7    -5.325495    6.636859   -0.537780   -2.082918    6.570510    0.076663
# 8   -15.008206   -6.078726   -9.206530   -6.034846   -7.019069    3.688301
# 9     6.806593   10.933386    8.032849    1.901069   -2.530311   11.253079
# 10  -10.133607    0.241013    8.268152   -5.968291  -14.536476    4.851660
# ...
